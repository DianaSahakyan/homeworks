# %% [markdown]
# # Scrape all movies from the IMDB Top 250 movies list.
# ## Maximum 50 points out of 100 (total exam)
# ## 1. For each movie you need to scrape:
# 1. Title = The Shawshank Redemption (6.25 points)
# 2. Rank of the movie from top 250 = 1 (6.25 points)
# 3. Year = 1994 (6.25 points)
# 4. Duration = 2h 22m (6.25 points)
# 5. Age rating (pg13, R etc.) = R (6.25 points)
# 6. Star rating = 9.3 (6.25 points)
# 7. Number of voters = 3M (6.25 points)
#
# ## 2. In the end create a dataframe with all the values and save it as a csv. (6.25 points)

# %% [markdown]
# ## Use the below code for requesting html info from the page.

# %%
from bs4 import BeautifulSoup
import requests

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36"
}

url = "https://www.imdb.com/chart/top/?ref_=nv_mv_250"
resp = requests.get(url, headers=headers)
print(resp.status_code)
# Out:
# 200

# %%
movie1.find("span", class_="ipc-rating-star--rating").text
d = []
for i in range(1, len(soup.find_all("span", class_="ipc-rating-star--rating")),3):
  d.append(soup.find_all("span", class_="ipc-rating-star--rating")[i].text)
d
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-cc583ec8841c> in <cell line: 1>()
# ----> 1 movie1.find("span", class_="ipc-rating-star--rating").text
#       2 d = []
#       3 for i in range(1, len(soup.find_all("span", class_="ipc-rating-star--rating")),3):
#       4   d.append(soup.find_all("span", class_="ipc-rating-star--rating")[i].text)
#       5 d
#
# NameError: name 'movie1' is not defined

# %%
movie1.find("span", class_="sc-5bc66c50-6 OOdsw cli-title-metadata-item").text
e = []
for i in range(1, len(soup.find_all("span", class_="sc-5bc66c50-6 OOdsw cli-title-metadata-item")),3):
  e.append(soup.find_all("span", class_="sc-5bc66c50-6 OOdsw cli-title-metadata-item")[i].text)
e
# Out:
# ['2h 22m',
#  '2h 55m',
#  '2h 32m',
#  '3h 22m',
#  '1h 36m',
#  '3h 21m',
#  '3h 15m',
#  '2h 34m',
#  '2h 58m',
#  '2h 58m',
#  '2h 22m',
#  '2h 59m',
#  '2h 19m',
#  '2h 28m',
#  '2h 4m',
#  '2h 16m',
#  '2h 25m',
#  '2h 13m',
#  '2h 49m',
#  '2h 7m',
#  '2h 10m',
#  '3h 27m',
#  '1h 58m',
#  '2h 49m',
#  '2h 10m']

# %%
movie1.find("span", class_="sc-5bc66c50-6 OOdsw cli-title-metadata-item").text
# Out:
# '1994'

# %%
a = []
for i in range(1, len(soup.find_all("span", class_="sc-5bc66c50-6 OOdsw cli-title-metadata-item")),3):
  a.append(soup.find_all("span", class_="sc-5bc66c50-6 OOdsw cli-title-metadata-item")[i].text)

# %%
year = []
for i in soup.find_all("span", class_="sc-5bc66c50-6 OOdsw cli-title-metadata-item")[1:]:
  year.append(i.text)
year
# Out:
# ['2h 22m',
#  'R',
#  '1972',
#  '2h 55m',
#  'R',
#  '2008',
#  '2h 32m',
#  'PG-13',
#  '1974',
#  '3h 22m',
#  'R',
#  '1957',
#  '1h 36m',
#  'Approved',
#  '2003',
#  '3h 21m',
#  'PG-13',
#  '1993',
#  '3h 15m',
#  'R',
#  '1994',
#  '2h 34m',
#  'R',
#  '2001',
#  '2h 58m',
#  'PG-13',
#  '1966',
#  '2h 58m',
#  'R',
#  '1994',
#  '2h 22m',
#  'PG-13',
#  '2002',
#  '2h 59m',
#  'PG-13',
#  '1999',
#  '2h 19m',
#  'R',
#  '2010',
#  '2h 28m',
#  'PG-13',
#  '1980',
#  '2h 4m',
#  'PG',
#  '1999',
#  '2h 16m',
#  'R',
#  '1990',
#  '2h 25m',
#  'R',
#  '1975',
#  '2h 13m',
#  'R',
#  '2014',
#  '2h 49m',
#  'PG-13',
#  '1995',
#  '2h 7m',
#  'R',
#  '1946',
#  '2h 10m',
#  'PG',
#  '1954',
#  '3h 27m',
#  'Not Rated',
#  '1991',
#  '1h 58m',
#  'R',
#  '1998',
#  '2h 49m',
#  'R',
#  '2002',
#  '2h 10m',
#  'R']

# %%
duration = []
for i in soup.find_all("span", class_="sc-5bc66c50-6 OOdsw cli-title-metadata-item")[1:]:
  duration.append(i.text)


duration
# Out:
# ['2h 22m',
#  'R',
#  '1972',
#  '2h 55m',
#  'R',
#  '2008',
#  '2h 32m',
#  'PG-13',
#  '1974',
#  '3h 22m',
#  'R',
#  '1957',
#  '1h 36m',
#  'Approved',
#  '2003',
#  '3h 21m',
#  'PG-13',
#  '1993',
#  '3h 15m',
#  'R',
#  '1994',
#  '2h 34m',
#  'R',
#  '2001',
#  '2h 58m',
#  'PG-13',
#  '1966',
#  '2h 58m',
#  'R',
#  '1994',
#  '2h 22m',
#  'PG-13',
#  '2002',
#  '2h 59m',
#  'PG-13',
#  '1999',
#  '2h 19m',
#  'R',
#  '2010',
#  '2h 28m',
#  'PG-13',
#  '1980',
#  '2h 4m',
#  'PG',
#  '1999',
#  '2h 16m',
#  'R',
#  '1990',
#  '2h 25m',
#  'R',
#  '1975',
#  '2h 13m',
#  'R',
#  '2014',
#  '2h 49m',
#  'PG-13',
#  '1995',
#  '2h 7m',
#  'R',
#  '1946',
#  '2h 10m',
#  'PG',
#  '1954',
#  '3h 27m',
#  'Not Rated',
#  '1991',
#  '1h 58m',
#  'R',
#  '1998',
#  '2h 49m',
#  'R',
#  '2002',
#  '2h 10m',
#  'R']

# %%
star_rating = []
for i in soup.find_all("span", class_="ipc-rating-star--rating")[1:]:
  star_rating.append(i.text)


star_rating
# Out:
# ['9.2',
#  '9.0',
#  '9.0',
#  '9.0',
#  '9.0',
#  '9.0',
#  '8.9',
#  '8.9',
#  '8.8',
#  '8.8',
#  '8.8',
#  '8.8',
#  '8.8',
#  '8.7',
#  '8.7',
#  '8.7',
#  '8.7',
#  '8.7',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6']

# %%
voters = []
for i in soup.find_all("span", class_="ipc-rating-star--voteCount")[1:]:
  voters.append(i.text)


voters
# Out:
# ['\xa0(2.1M)',
#  '\xa0(2.9M)',
#  '\xa0(1.4M)',
#  '\xa0(894K)',
#  '\xa0(2M)',
#  '\xa0(1.5M)',
#  '\xa0(2.3M)',
#  '\xa0(2.1M)',
#  '\xa0(831K)',
#  '\xa0(2.3M)',
#  '\xa0(1.8M)',
#  '\xa0(2.4M)',
#  '\xa0(2.6M)',
#  '\xa0(1.4M)',
#  '\xa0(2.1M)',
#  '\xa0(1.3M)',
#  '\xa0(1.1M)',
#  '\xa0(2.2M)',
#  '\xa0(1.9M)',
#  '\xa0(510K)',
#  '\xa0(376K)',
#  '\xa0(1.6M)',
#  '\xa0(1.5M)',
#  '\xa0(819K)']

# %% [markdown]
# # Bonus question (10 points)
# ## For each movie also scrape the director name.
